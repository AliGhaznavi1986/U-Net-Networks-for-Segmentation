# %% [markdown]
# # Req Lib

# %%
#Required Lib
"""
Created on Sep 19 09:55:13 2021
@author: alighaznavi
"""
import tensorflow as tf
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import backend as K
import numpy as np
import cv2
import pandas as pd
import glob
import pickle
from matplotlib import pyplot as plt
from skimage.transform import resize
from skimage import measure, color, io
import os
from tensorflow.keras.optimizers import Adam
from datetime import datetime 
# !pip install git+https://github.com/artemmavrin/focal-loss.git     #install Focal loss
from focal_loss import BinaryFocalLoss
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Activation, MaxPool2D, Concatenate
# Out:
# Collecting git+https://github.com/artemmavrin/focal-loss.git
#   Cloning https://github.com/artemmavrin/focal-loss.git to /tmp/pip-req-build-fdxhcqvd
#   Running command git clone -q https://github.com/artemmavrin/focal-loss.git /tmp/pip-req-build-fdxhcqvd
# Requirement already satisfied: tensorflow>=2.2 in /usr/local/lib/python3.7/dist-packages (from focal-loss==0.0.8) (2.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (1.14.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (3.1.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (2.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (4.2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (0.2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (2.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (1.44.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (0.25.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 5.3 MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (3.3.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (1.0.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (1.21.6)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (1.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (57.4.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (3.17.3)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (0.5.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (1.15.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2->focal-loss==0.0.8) (14.0.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.2->focal-loss==0.0.8) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=2.2->focal-loss==0.0.8) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (3.3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.2->focal-loss==0.0.8) (3.2.0)
# Building wheels for collected packages: focal-loss
#   Building wheel for focal-loss (setup.py) ... done
#   Created wheel for focal-loss: filename=focal_loss-0.0.8-py3-none-any.whl size=19050 sha256=6284cc87149db998ce99fe76e2fa12502523cdb38072bd4c445e39ea4937e5a2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-414rcxgt/wheels/a2/9b/0f/a4d351aeb42d31330a290569400d5ff7bb54938658a508e9cd
# Successfully built focal-loss
# Installing collected packages: tf-estimator-nightly, focal-loss
# Successfully installed focal-loss-0.0.8 tf-estimator-nightly-2.8.0.dev2021122109

# %% [markdown]
# #Mounth Google Drive

# %%
# !pwd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /content
# Mounted at /content/drive

# %% [markdown]
# #Image Generator for the Image

# %%
seed=24
batch_size= 4
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_gen_args = dict(rescale = 1/255.,   
                         rotation_range=90,
                      width_shift_range=0.3,
                      height_shift_range=0.3,
                      shear_range=0.5,
                      zoom_range=0.3,
                      horizontal_flip=True,
                      vertical_flip=True,
                      fill_mode='reflect')

mask_gen_args = dict(rescale = 1/255.,  
                        rotation_range=90,
                      width_shift_range=0.3,
                      height_shift_range=0.3,
                      shear_range=0.5,
                      zoom_range=0.3,
                      horizontal_flip=True,
                      vertical_flip=True,
                      fill_mode='reflect',
                      preprocessing_function = lambda x: np.where(x>0, 1, 0).astype(x.dtype)) #Binarize the output again.

# %% [markdown]
# # Load data from drive

# %%
image_data_generator = ImageDataGenerator(**img_gen_args)
image_generator = image_data_generator.flow_from_directory("/content/drive/MyDrive/Colab Notebooks/data/spilit_x_image_train/", 
                                                           seed=seed, 
                                                           batch_size=batch_size,
                                                           target_size=(512, 512),
                                                           class_mode=None)   
                                                                            

mask_data_generator = ImageDataGenerator(**mask_gen_args)
mask_generator = mask_data_generator.flow_from_directory("/content/drive/MyDrive/Colab Notebooks/data/spilit_y_mask_train/", 
                                                         seed=seed, 
                                                         batch_size=batch_size,
                                                         target_size=(512, 512),
                                                         color_mode = 'grayscale',   #Read masks in grayscale
                                                         class_mode=None)


valid_img_generator = image_data_generator.flow_from_directory("/content/drive/MyDrive/Colab Notebooks/data/spilit_x_image_validate/", 
                                                               seed=seed, 
                                                               batch_size=batch_size, 
                                                               target_size=(512, 512),
                                                               class_mode=None) #Default batch size 32, if not specified here
valid_mask_generator = mask_data_generator.flow_from_directory("/content/drive/MyDrive/Colab Notebooks/data/spilit_y_mask_validate/", 
                                                               seed=seed, 
                                                               batch_size=batch_size, 
                                                               target_size=(512, 512),
                                                               color_mode = 'grayscale',   #Read masks in grayscale
                                                               class_mode=None)  #Default batch size 32, if not specified here

training_set_generator = zip(image_generator, mask_generator)
#train_generator = zip(image_generator, mask_generator)
#val_generator = zip(valid_img_generator, valid_mask_generator)
validation_set_generator = zip(valid_img_generator, valid_mask_generator)
# Out:
# Found 320 images belonging to 1 classes.
# Found 320 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.
# Found 80 images belonging to 1 classes.

# %% [markdown]
# # Test Loaded Data

# %%
p = image_generator.next()
q = mask_generator.next()
for i in range(0,1):
    image = p[i]
    mask = q[i]
    plt.figure(figsize=(12, 6))
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.title('Train Image')
    #plt.imshow(image[:,:,0], cmap='gray')
    plt.subplot(1,2,2)
    plt.imshow(mask[:,:,0], cmap='gray')
    plt.title('G T')
    plt.show()

# %% [markdown]
# # Req Parameter to setup

# %%
IMG_HEIGHT = p.shape[1]
IMG_WIDTH  = p.shape[2]
IMG_CHANNELS = p.shape[3]
num_labels = 1  #Binary
input_shape = (IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)
batch_size = 8

# %% [markdown]
# some Metrics for evaliation

# %%
def dice_coeficient(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)


def jacard_coeficient(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)


def jacard_coeficient_loss(y_true, y_pred):
    return -jacard_coeficient(y_true, y_pred)


def dice_coeficient_loss(y_true, y_pred):
    return -dice_coeficient(y_true, y_pred)

# %% [markdown]
# Useful blocks to build Unet
# conv - BN - Activation - conv - BN - Activation - Dropout (if enabled)

# %%
def convolutional_block(x, filter_size, size, dropout, batch_norm=False):
    
    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("LeakyReLU")(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("LeakyReLU")(conv)
    
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    return conv

# %% [markdown]
# Repeating Element

# %%
def repeating_element(tensor, rep):
    # lambda function to repeat the elements of a tensor along an axis
    #by a factor of repitation.
    # If tensor has shape (--, 512,512,3), lambda return a tensor with the shape
    # of shape (--, 512,512,6), if specified axis=3 and repitation=2.

     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)

# %% [markdown]
# Define Residual Convolutional Block

# %%
def residual_convolutional_block(x, filter_size, size, dropout, batch_norm=False):
    '''
    Residual convolutional layer.
    Two variants....                                 
    '''

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation('LeakyReLU')(conv)
    
    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    shortcut = layers.Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)

    res_path = layers.add([shortcut, conv])
    res_path = layers.Activation('LeakyReLU')(res_path)  
    return res_path

# %% [markdown]
# Gating Signal Func

# %%
def gating_signal_for_Att(input, out_size, batch_norm=False):

    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

# %% [markdown]
# Define ATT Blocks

# %%
def soft_attention_block_str(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

#  x signal will recive the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  
    shape_theta_x = K.int_shape(theta_x)

#  gating signal with the same number of filters of the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g) 

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg) 

    upsample_psi = repeating_element(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn

# %% [markdown]
# # Simple Unet

# %%
def Simple_UNet(input_shape, NUM_CLASSES=1, dropout_rate=0.05, batch_norm=True):
    '''
    UNet, 
    
    '''   
    # required parameters for the network structure
    FILTER_NUM = 64 #  filters number for the first layer
    FILTER_SIZE = 3 # convolutional filter size
    UP_SAMP_SIZE = 2 # upsampling filters size

    inputs = layers.Input(input_shape, dtype=tf.float32)

    # Downsampling layers
    # Downsampling 1, convolution + pooling
    conv_128 = convolutional_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # Downsampling 2
    conv_64 = convolutional_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # Downsampling 3
    conv_32 = convolutional_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # Downsampling 4
    conv_16 = convolutional_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # Downsampling 5, convolution only
    conv_8 = convolutional_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers 
    
    # Upsampleling 6
   
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = layers.concatenate([up_16, conv_16], axis=3)
    up_conv_16 = convolutional_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # Upsampleling 7
    
    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, conv_32], axis=3)
    up_conv_32 = convolutional_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # Upsampleling 8
    
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, conv_64], axis=3)
    up_conv_64 = convolutional_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # Upsampleling 9
   
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, conv_128], axis=3)
    up_conv_128 = convolutional_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # convolutional layers (1*1)
   
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    conv_final = layers.Activation('sigmoid')(conv_final)  

    # Simple_Unet_Model 
    model = models.Model(inputs, conv_final, name="UNet")
    print(model.summary())
    return model

# %% [markdown]
# #Run Normal Unet

# %%
'''
UNet
'''
simple_unet_model = Simple_UNet(input_shape)
simple_unet_model.compile(optimizer=Adam(lr = 1e-3), loss=BinaryFocalLoss(gamma=2), 
              metrics=['accuracy', jacard_coeficient])
earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 15,
                          verbose = 1,
                          restore_best_weights = True)


print(simple_unet_model.summary())

start1 = datetime.now() 
simple_unet_history = simple_unet_model.fit(training_set_generator, 
                    verbose=1,
                    batch_size = batch_size,
                    validation_data= validation_set_generator, steps_per_epoch=100, 
                    validation_steps=100,
                    shuffle=False,
                    epochs=100, callbacks=[earlystop])

stop1 = datetime.now()
#calculate run time of the model 
execution_time_Unet = stop1-start1
print("UNet execution time is: ", execution_time_Unet)

simple_unet_model.save('U_Net_100EP_Correct Dataset_LE-3.hdf5')
# Out:
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 512, 512, 64  0           ['activation_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['dropout[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  dropout_1 (Dropout)            (None, 256, 256, 12  0           ['activation_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['dropout_1[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  dropout_2 (Dropout)            (None, 128, 128, 25  0           ['activation_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['dropout_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 64, 64, 512)  0           ['activation_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['dropout_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 32, 32, 1024  0           ['activation_9[0][0]']
#                                 )
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 1024  0           ['dropout_4[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 64, 64, 1536  0           ['up_sampling2d[0][0]',
#                                 )                                 'dropout_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  7078400     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  dropout_5 (Dropout)            (None, 64, 64, 512)  0           ['activation_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 51  0          ['dropout_5[0][0]']
#                                 2)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 76  0           ['up_sampling2d_1[0][0]',
#                                 8)                                'dropout_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1769728     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  dropout_6 (Dropout)            (None, 128, 128, 25  0           ['activation_13[0][0]']
#                                 6)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 25  0          ['dropout_6[0][0]']
#                                 6)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 38  0           ['up_sampling2d_2[0][0]',
#                                 4)                                'dropout_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  442496      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  dropout_7 (Dropout)            (None, 256, 256, 12  0           ['activation_15[0][0]']
#                                 8)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 512, 512, 12  0          ['dropout_7[0][0]']
#                                 8)
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 19  0           ['up_sampling2d_3[0][0]',
#                                 2)                                'dropout[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  110656      ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 512, 512, 64  0           ['activation_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['dropout_8[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 512, 512, 1)  4          ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 512, 512, 1)  0           ['batch_normalization_18[0][0]']
#
# ==================================================================================================
# Total params: 31,402,501
# Trainable params: 31,390,723
# Non-trainable params: 11,778
# __________________________________________________________________________________________________
# None
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 512, 512, 64  0           ['activation_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['dropout[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  dropout_1 (Dropout)            (None, 256, 256, 12  0           ['activation_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['dropout_1[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  dropout_2 (Dropout)            (None, 128, 128, 25  0           ['activation_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['dropout_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 64, 64, 512)  0           ['activation_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['dropout_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 32, 32, 1024  0           ['activation_9[0][0]']
#                                 )
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 1024  0           ['dropout_4[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 64, 64, 1536  0           ['up_sampling2d[0][0]',
#                                 )                                 'dropout_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  7078400     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  dropout_5 (Dropout)            (None, 64, 64, 512)  0           ['activation_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 51  0          ['dropout_5[0][0]']
#                                 2)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 76  0           ['up_sampling2d_1[0][0]',
#                                 8)                                'dropout_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1769728     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  dropout_6 (Dropout)            (None, 128, 128, 25  0           ['activation_13[0][0]']
#                                 6)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 25  0          ['dropout_6[0][0]']
#                                 6)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 38  0           ['up_sampling2d_2[0][0]',
#                                 4)                                'dropout_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  442496      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  dropout_7 (Dropout)            (None, 256, 256, 12  0           ['activation_15[0][0]']
#                                 8)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 512, 512, 12  0          ['dropout_7[0][0]']
#                                 8)
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 19  0           ['up_sampling2d_3[0][0]',
#                                 2)                                'dropout[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  110656      ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 512, 512, 64  0           ['activation_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['dropout_8[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 512, 512, 1)  4          ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 512, 512, 1)  0           ['batch_normalization_18[0][0]']
#
# ==================================================================================================
# Total params: 31,402,501
# Trainable params: 31,390,723
# Non-trainable params: 11,778
# __________________________________________________________________________________________________
# None
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/100
# 100/100 [==============================] - 539s 5s/step - loss: 0.1084 - accuracy: 0.8063 - jacard_coef: 8.9881e-04 - val_loss: 3.2646 - val_accuracy: 0.0031 - val_jacard_coef: 5.5234e-04
# Epoch 2/100
# 100/100 [==============================] - 131s 1s/step - loss: 0.0844 - accuracy: 0.8178 - jacard_coef: 9.8579e-04 - val_loss: 0.1058 - val_accuracy: 0.8573 - val_jacard_coef: 5.7204e-04
# Epoch 3/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.0737 - accuracy: 0.8267 - jacard_coef: 9.9237e-04 - val_loss: 0.1034 - val_accuracy: 0.8585 - val_jacard_coef: 5.8306e-04
# Epoch 4/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.0655 - accuracy: 0.8278 - jacard_coef: 0.0010 - val_loss: 0.0971 - val_accuracy: 0.8601 - val_jacard_coef: 6.1555e-04
# Epoch 5/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.0571 - accuracy: 0.8291 - jacard_coef: 0.0011 - val_loss: 0.0604 - val_accuracy: 0.8471 - val_jacard_coef: 8.4844e-04
# Epoch 6/100
# 100/100 [==============================] - 132s 1s/step - loss: 0.0557 - accuracy: 0.8267 - jacard_coef: 0.0011 - val_loss: 0.0727 - val_accuracy: 0.8447 - val_jacard_coef: 8.2238e-04
# Epoch 7/100
# 100/100 [==============================] - 129s 1s/step - loss: 0.
100
# 100/100 [==============================] - 130s 1s/step - loss: 0.0232 - accuracy: 0.8404 - jacard_coef: 0.0020 - val_loss: 0.0708 - val_accuracy: 0.7032 - val_jacard_coef: 0.0013
# Epoch 89/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.0227 - accuracy: 0.8363 - jacard_coef: 0.0020 - val_loss: 0.0250 - val_accuracy: 0.8424 - val_jacard_coef: 0.0019
# Epoch 90/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.0235 - accuracy: 0.8371 - jacard_coef: 0.0020 - val_loss: 0.0463 - val_accuracy: 0.8361 - val_jacard_coef: 0.0015
# Epoch 91/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.0271 - accuracy: 0.8409 - jacard_coef: 0.0019 - val_loss: 0.0320 - val_accuracy: 0.8370 - val_jacard_coef: 0.0017
# Epoch 92/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.0235 - accuracy: 0.8354 - jacard_coef: 0.0020 - val_loss: 0.0359 - val_accuracy: 0.8417 - val_jacard_coef: 0.0016
# Epoch 93/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.0262 - accuracy: 0.8364 - jacard_coef: 0.0020 - val_loss: 0.0289 - val_accuracy: 0.8389 - val_jacard_coef: 0.0019
# Epoch 94/100
# 100/100 [==============================] - 129s 1s/step - loss: 0.0252 - accuracy: 0.8386 - jacard_coef: 0.0020 - val_loss: 0.0279 - val_accuracy: 0.8473 - val_jacard_coef: 0.0019
# Epoch 95/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.0256 - accuracy: 0.8360 - jacard_coef: 0.0020 - val_loss: 0.0283 - val_accuracy: 0.8418 - val_jacard_coef: 0.0020
# Epoch 96/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.0228 - accuracy: 0.8391 - jacard_coef: 0.0020 - val_loss: 0.0278 - val_accuracy: 0.8428 - val_jacard_coef: 0.0020
# Epoch 97/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.0253 - accuracy: 0.8372 - jacard_coef: 0.0020 - val_loss: 0.0316 - val_accuracy: 0.8400 - val_jacard_coef: 0.0017
# Epoch 98/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.0247 - accuracy: 0.8381 - jacard_coef: 0.0020 - val_loss: 0.0266 - val_accuracy: 0.8429 - val_jacard_coef: 0.0019
# Epoch 99/100
# 100/100 [==============================] - 129s 1s/step - loss: 0.0223 - accuracy: 0.8383 - jacard_coef: 0.0020 - val_loss: 0.0290 - val_accuracy: 0.8382 - val_jacard_coef: 0.0017
# Epoch 100/100
# 100/100 [==============================] - 130s 1s/step - loss: 0.0224 - accuracy: 0.8406 - jacard_coef: 0.0020 - val_loss: 0.0262 - val_accuracy: 0.8452 - val_jacard_coef: 0.0019
# UNet execution time is:  3:42:18.138577

# %% [markdown]
# # Soft Attention Unet

# %%
def addetive_sotf_Attention_UNet(input_shape, NUM_CLASSES=1, dropout_rate=0.05, batch_norm=True):
    '''
    Attention UNet, 
    
    '''
    # required parameters for the network structure
    FILTER_NUM = 64 #  filters number for the first layer
    FILTER_SIZE = 3 # convolutional filter size
    UP_SAMP_SIZE = 2 # upsampling filters size
    
    inputs = layers.Input(input_shape, dtype=tf.float32)

    # Downsampling layers
    # Downsampling 1, convolution + pooling
    conv_128 = convolutional_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # Downsampling 2
    conv_64 = convolutional_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # Downsampling 3
    conv_32 = convolutional_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # Downsampling 4
    conv_16 = convolutional_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # Downsampling 5, convolution only
    conv_8 = convolutional_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers

    # Upsampling 6,
    gating_16 = gating_signal_for_Att(conv_8, 8*FILTER_NUM, batch_norm)
    att_16 = soft_attention_block_str(conv_16, gating_16, 8*FILTER_NUM)
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = layers.concatenate([up_16, att_16], axis=3)
    up_conv_16 = convolutional_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # Upsampling 7
    gating_32 = gating_signal_for_Att(up_conv_16, 4*FILTER_NUM, batch_norm)
    att_32 = soft_attention_block_str(conv_32, gating_32, 4*FILTER_NUM)
    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=3)
    up_conv_32 = convolutional_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # Upsampling 8
    gating_64 = gating_signal_for_Att(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = soft_attention_block_str(conv_64, gating_64, 2*FILTER_NUM)
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=3)
    up_conv_64 = convolutional_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # Upsampling 9
    gating_128 = gating_signal_for_Att(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = soft_attention_block_str(conv_128, gating_128, FILTER_NUM)
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=3)
    up_conv_128 = convolutional_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # convolutional layers (1*1)
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    conv_final = layers.Activation('sigmoid')(conv_final)  

    # Attention Unet Model 
    model = models.Model(inputs, conv_final, name="Attention_UNet")
    return model

# %% [markdown]
# # Run Soft Attention U-Net

# %%
'''
Attention UNet
'''
Attention_unet_model = addetive_sotf_Attention_UNet(input_shape)

Attention_unet_model.compile(optimizer=Adam(lr = 1e-3), loss=BinaryFocalLoss(gamma=2), 
              metrics=['accuracy', jacard_coeficient, ])

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 15,
                          verbose = 1,
                          restore_best_weights = True)

print(Attention_unet_model.summary())
start2 = datetime.now() 
Attention_unet_history = Attention_unet_model.fit(training_set_generator, 
                    verbose=1,
                    batch_size = batch_size,
                    validation_data= validation_set_generator, steps_per_epoch=100, 
                    validation_steps=100, 
                    shuffle=False,
                    epochs=100, callbacks=[earlystop])
stop2 = datetime.now()
#Calculate run time of the model 
execution_time_Att_Unet = stop2-start2
print("Attention UNet execution time is: ", execution_time_Att_Unet)

Attention_unet_model.save('Attention_UNet_100epochs_B_focal_Leakyrelu_Lr-3.hdf5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "Attention_UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 512, 512, 64  0           ['activation_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['dropout[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  dropout_1 (Dropout)            (None, 256, 256, 12  0           ['activation_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['dropout_1[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  dropout_2 (Dropout)            (None, 128, 128, 25  0           ['activation_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['dropout_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 64, 64, 512)  0           ['activation_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['dropout_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 32, 32, 1024  0           ['activation_9[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  524800      ['dropout_4[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 512)  262656      ['activation_10[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 512)  2359808    ['conv2d_12[0][0]']
#  ose)
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  1049088     ['dropout_3[0][0]']
#
#  add (Add)                      (None, 32, 32, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  activation_11 (Activation)     (None, 32, 32, 512)  0           ['add[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 1)    513         ['activation_11[0][0]']
#
#  activation_12 (Activation)     (None, 32, 32, 1)    0           ['conv2d_13[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 1)    0           ['activation_12[0][0]']
#
#  lambda (Lambda)                (None, 64, 64, 512)  0           ['up_sampling2d[0][0]']
#
#  multiply (Multiply)            (None, 64, 64, 512)  0           ['lambda[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 512)  262656      ['multiply[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 1024  0          ['dropout_4[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_14[0][0]']
#  ormalization)
#
#  concatenate (Concatenate)      (None, 64, 64, 1536  0           ['up_sampling2d_1[0][0]',
#                                 )                                 'batch_normalization_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 512)  7078400     ['concatenate[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_13[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_13[0][0]']
#
#  dropout_5 (Dropout)            (None, 64, 64, 512)  0           ['activation_14[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 256)  131328      ['dropout_5[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 256)  65792       ['activation_15[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 256)  590080     ['conv2d_19[0][0]']
#  spose)
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 256)  262400      ['dropout_2[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  activation_16 (Activation)     (None, 64, 64, 256)  0           ['add_1[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 1)    257         ['activation_16[0][0]']
#
#  activation_17 (Activation)     (None, 64, 64, 1)    0           ['conv2d_20[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 1)  0          ['activation_17[0][0]']
#
#  lambda_1 (Lambda)              (None, 128, 128, 25  0           ['up_sampling2d_2[0][0]']
#                                 6)
#
#  multiply_1 (Multiply)          (None, 128, 128, 25  0           ['lambda_1[0][0]',
#                                 6)                                'dropout_2[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 25  65792       ['multiply_1[0][0]']
#                                 6)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 51  0          ['dropout_5[0][0]']
#                                 2)
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 25  1024       ['conv2d_21[0][0]']
#  ormalization)                  6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 76  0           ['up_sampling2d_3[0][0]',
#                                 8)                                'batch_normalization_15[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 25  1769728     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 25  1024       ['conv2d_22[0][0]']
#  ormalization)                  6)
#
#  activation_18 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_16[0][0]']
#                                 6)
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 25  590080      ['activation_18[0][0]']
#                                 6)
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 25  1024       ['conv2d_23[0][0]']
#  ormalization)                  6)
#
#  activation_19 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_17[0][0]']
#                                 6)
#
#  dropout_6 (Dropout)            (None, 128, 128, 25  0           ['activation_19[0][0]']
#                                 6)
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 12  32896       ['dropout_6[0][0]']
#                                 8)
#
#  batch_normalization_18 (BatchN  (None, 128, 128, 12  512        ['conv2d_24[0][0]']
#  ormalization)                  8)
#
#  activation_20 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_18[0][0]']
#                                 8)
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 12  16512       ['activation_20[0][0]']
#                                 8)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 12  147584     ['conv2d_26[0][0]']
#  spose)                         8)
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 12  65664       ['dropout_1[0][0]']
#                                 8)
#
#  add_2 (Add)                    (None, 128, 128, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                'conv2d_25[0][0]']
#
#  activation_21 (Activation)     (None, 128, 128, 12  0           ['add_2[0][0]']
#                                 8)
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 1)  129         ['activation_21[0][0]']
#
#  activation_22 (Activation)     (None, 128, 128, 1)  0           ['conv2d_27[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 1)  0          ['activation_22[0][0]']
#
#  lambda_2 (Lambda)              (None, 256, 256, 12  0           ['up_sampling2d_4[0][0]']
#                                 8)
#
#  multiply_2 (Multiply)          (None, 256, 256, 12  0           ['lambda_2[0][0]',
#                                 8)                                'dropout_1[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 256, 256, 12  16512       ['multiply_2[0][0]']
#                                 8)
#
#  up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 25  0          ['dropout_6[0][0]']
#                                 6)
#
#  batch_normalization_19 (BatchN  (None, 256, 256, 12  512        ['conv2d_28[0][0]']
#  ormalization)                  8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 38  0           ['up_sampling2d_5[0][0]',
#                                 4)                                'batch_normalization_19[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 256, 256, 12  442496      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_20 (BatchN  (None, 256, 256, 12  512        ['conv2d_29[0][0]']
#  ormalization)                  8)
#
#  activation_23 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_20[0][0]']
#                                 8)
#
#  conv2d_30 (Conv2D)             (None, 256, 256, 12  147584      ['activation_23[0][0]']
#                                 8)
#
#  batch_normalization_21 (BatchN  (None, 256, 256, 12  512        ['conv2d_30[0][0]']
#  ormalization)                  8)
#
#  activation_24 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_21[0][0]']
#                                 8)
#
#  dropout_7 (Dropout)            (None, 256, 256, 12  0           ['activation_24[0][0]']
#                                 8)
#
#  conv2d_31 (Conv2D)             (None, 256, 256, 64  8256        ['dropout_7[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 256, 256, 64  256        ['conv2d_31[0][0]']
#  ormalization)                  )
#
#  activation_25 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 256, 256, 64  4160        ['activation_25[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 64  36928      ['conv2d_33[0][0]']
#  spose)                         )
#
#  conv2d_32 (Conv2D)             (None, 256, 256, 64  16448       ['dropout[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 256, 256, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_32[0][0]']
#
#  activation_26 (Activation)     (None, 256, 256, 64  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 256, 256, 1)  65          ['activation_26[0][0]']
#
#  activation_27 (Activation)     (None, 256, 256, 1)  0           ['conv2d_34[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 512, 512, 1)  0          ['activation_27[0][0]']
#
#  lambda_3 (Lambda)              (None, 512, 512, 64  0           ['up_sampling2d_6[0][0]']
#                                 )
#
#  multiply_3 (Multiply)          (None, 512, 512, 64  0           ['lambda_3[0][0]',
#                                 )                                 'dropout[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 512, 512, 64  4160        ['multiply_3[0][0]']
#                                 )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 512, 512, 12  0          ['dropout_7[0][0]']
#                                 8)
#
#  batch_normalization_23 (BatchN  (None, 512, 512, 64  256        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 19  0           ['up_sampling2d_7[0][0]',
#                                 2)                                'batch_normalization_23[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 512, 512, 64  110656      ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 512, 512, 64  256        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_28 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_24[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 512, 512, 64  36928       ['activation_28[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 512, 512, 64  256        ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  activation_29 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 512, 512, 64  0           ['activation_29[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 512, 512, 1)  65          ['dropout_8[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 512, 512, 1)  4          ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 512, 512, 1)  0           ['batch_normalization_26[0][0]']
#
# ==================================================================================================
# Total params: 37,334,665
# Trainable params: 37,319,047
# Non-trainable params: 15,618
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 100/100 [==============================] - 360s 4s/step - loss: 0.1073 - accuracy: 0.8107 - jacard_coef: 9.0322e-04 - val_loss: 2.1569 - val_accuracy: 0.0401 - val_jacard_coef: 5.9083e-04
# Epoch 2/100
# 100/100 [==============================] - 142s 1s/step - loss: 0.0849 - accuracy: 0.8198 - jacard_coef: 9.8307e-04 - val_loss: 0.1843 - val_accuracy: 0.4168 - val_jacard_coef: 6.6599e-04
# Epoch 3/100
# 100/100 [==============================] - 141s 1s/step - loss: 0.0756 - accuracy: 0.8272 - jacard_coef: 9.8797e-04 - val_loss: 0.1045 - val_accuracy: 0.8547 - val_jacard_coef: 6.0990e-04
# Epoch 4/100
# 100/100 [==============================] - 145s 1s/step - loss: 0.0661 - accuracy: 0.8279 - jacard_coef: 0.0010 - val_loss: 0.0979 - val_accuracy: 0.8601 - val_jacard_coef: 5.9481e-04
# Epoch 5/100
# 100/100 [==============================] - 144s 1s/step - loss: 0.0605 - accuracy: 0.8278 - jacard_coef: 0.0011 - val_loss: 0.0779 - val_accuracy: 0.8568 - val_jacard_coef: 7.3535e-04
# Epoch 6/100
# 100/100 [==============================] - 142s 1s/step - loss: 0.0577 - accuracy: 0.8266 - jacard_coef: 0.0011 - val_loss: 1.0490 - val_accuracy: 0.1032 - val_jacard_coef: 6.3339e-04
# Epoch 7/100
# 100/100 [==============================] - 144s 1s/step - loss: 0.0529 - accuracy: 0.8314 - jacard_coef: 0.0011 - val_loss: 0.0509 - val_accuracy: 0.8445 - val_jacard_coef: 0.0011
# Epoch 8/100
# 100/100 [==============================] - 144s 1s/step - loss: 0.0457 - accuracy: 0.8327 - jacard_coef: 0.0012 - val_loss: 0.0524 - val_accuracy: 0.8495 - val_jacard_coef: 0.0010
# Epoch 9/100
# 100/100 [==============================] - 165s 2s/step - loss: 0.0454 - accuracy: 0.8314 - jacard_coef: 0.0012 - val_loss: 0.0909 - val_accuracy: 0.8326 - val_jacard_coef: 8.9495e-04
# Epoch 10/100
# 100/100 [==============================] - 147s 1s/step - loss: 0.
UM_CLASSES=1, dropout_rate=0.0, batch_norm=True):
    '''
    Rsidual UNet, with attention 
    
    '''
    # required parameters for the Residual Attention unet network structure
    FILTER_NUM = 64 #  filters number for the first layer
    FILTER_SIZE = 3 # convolutional filter size
    UP_SAMP_SIZE = 2 # upsampling filters size

    # Input image dimension 
    inputs = layers.Input(input_shape, dtype=tf.float32)
    axis = 3

    # Downsampling layers
    # DownResidual 1
    conv_128 = residual_convolutional_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownResidual 2
    conv_64 = residual_convolutional_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownResidual 3
    conv_32 = residual_convolutional_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # DownResidual 4
    conv_16 = residual_convolutional_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # DownResidual 5, convolution only
    conv_8 = residual_convolutional_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers
    # UpResidual 6, 
    gating_16 = gating_signal_for_Att(conv_8, 8*FILTER_NUM, batch_norm)
    att_16 = soft_attention_block_str(conv_16, gating_16, 8*FILTER_NUM)
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = layers.concatenate([up_16, att_16], axis=axis)
    up_conv_16 = residual_convolutional_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpResidual 7
    gating_32 = gating_signal_for_Att(up_conv_16, 4*FILTER_NUM, batch_norm)
    att_32 = soft_attention_block_str(conv_32, gating_32, 4*FILTER_NUM)
    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=axis)
    up_conv_32 = residual_convolutional_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpResidual 8
    gating_64 = gating_signal_for_Att(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = soft_attention_block_str(conv_64, gating_64, 2*FILTER_NUM)
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=axis)
    up_conv_64 = residual_convolutional_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpResidual 9
    gating_128 = gating_signal_for_Att(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = soft_attention_block_str(conv_128, gating_128, FILTER_NUM)
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=axis)
    up_conv_128 = residual_convolutional_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    #convolutional layers (1*1)
    
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=axis)(conv_final)
    conv_final = layers.Activation('sigmoid')(conv_final) 

    # Residual Attention unet Model 
    model = models.Model(inputs, conv_final, name="AttentionResUNet")
    return model

# %% [markdown]
# # Running Residual Unet

# %%
'''
Residual soft Attention Unet
'''
Residual_Attention_UNet_model = Residual_Attention_UNet(input_shape)

Residual_Attention_UNet_model.compile(optimizer=Adam(lr = 1e-3), loss=BinaryFocalLoss(gamma=2), 
              metrics=['accuracy', jacard_coeficient, 'Recall'])

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 15,
                          verbose = 1,
                          restore_best_weights = True)

print(Residual_Attention_UNet_model.summary())


start3 = datetime.now() 
Residual_Attention_UNet_history = Residual_Attention_UNet_model.fit(training_set_generator, 
                    verbose=1,
                    batch_size = batch_size,
                    validation_data= validation_set_generator, steps_per_epoch=100, 
                    validation_steps=100, 
                    shuffle=False,
                    epochs=150)
stop3 = datetime.now()

#calculate run time of the model 
execution_time_AttResUnet = stop3-start3
print("Attention ResUnet execution time is: ", execution_time_AttResUnet)

Residual_Attention_UNet_model.save('AttResUnet_100epochs_B_focal_LeakyRelu.hdf5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "AttentionResUNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 512, 512, 64  256         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 512, 512, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 512, 512, 64  0           ['batch_normalization_2[0][0]',
#                                 )                                 'batch_normalization_1[0][0]']
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['add[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 12  8320        ['max_pooling2d[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_5 (BatchNo  (None, 256, 256, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  batch_normalization_4 (BatchNo  (None, 256, 256, 12  512        ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  add_1 (Add)                    (None, 256, 256, 12  0           ['batch_normalization_5[0][0]',
#                                 8)                                'batch_normalization_4[0][0]']
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['add_1[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_6 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_6 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_6[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_6[0][0]']
#                                 6)
#
#  conv2d_8 (Conv2D)              (None, 128, 128, 25  33024       ['max_pooling2d_1[0][0]']
#                                 6)
#
#  conv2d_7 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_8 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_8[0][0]']
#  rmalization)                   6)
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_7[0][0]']
#  rmalization)                   6)
#
#  add_2 (Add)                    (None, 128, 128, 25  0           ['batch_normalization_8[0][0]',
#                                 6)                                'batch_normalization_7[0][0]']
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['add_2[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  131584      ['max_pooling2d_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['add_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 1024  525312      ['max_pooling2d_3[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  add_4 (Add)                    (None, 32, 32, 1024  0           ['batch_normalization_14[0][0]',
#                                 )                                 'batch_normalization_13[0][0]']
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 512)  524800      ['activation_9[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 512)  262656      ['activation_10[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 512)  2359808    ['conv2d_17[0][0]']
#  ose)
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 512)  1049088     ['activation_7[0][0]']
#
#  add_5 (Add)                    (None, 32, 32, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  activation_11 (Activation)     (None, 32, 32, 512)  0           ['add_5[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 1)    513         ['activation_11[0][0]']
#
#  activation_12 (Activation)     (None, 32, 32, 1)    0           ['conv2d_18[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 1)    0           ['activation_12[0][0]']
#
#  lambda (Lambda)                (None, 64, 64, 512)  0           ['up_sampling2d[0][0]']
#
#  multiply (Multiply)            (None, 64, 64, 512)  0           ['lambda[0][0]',
#                                                                   'activation_7[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 512)  262656      ['multiply[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 1024  0          ['activation_9[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_19[0][0]']
#  ormalization)
#
#  concatenate (Concatenate)      (None, 64, 64, 1536  0           ['up_sampling2d_1[0][0]',
#                                 )                                 'batch_normalization_16[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 512)  7078400     ['concatenate[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 512)  786944      ['concatenate[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_13[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_21[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 64, 64, 512)  0           ['batch_normalization_19[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  activation_14 (Activation)     (None, 64, 64, 512)  0           ['add_6[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 256)  131328      ['activation_14[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 256)  65792       ['activation_15[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 256)  590080     ['conv2d_25[0][0]']
#  spose)
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 256)  262400      ['activation_5[0][0]']
#
#  add_7 (Add)                    (None, 64, 64, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  activation_16 (Activation)     (None, 64, 64, 256)  0           ['add_7[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 1)    257         ['activation_16[0][0]']
#
#  activation_17 (Activation)     (None, 64, 64, 1)    0           ['conv2d_26[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 1)  0          ['activation_17[0][0]']
#
#  lambda_1 (Lambda)              (None, 128, 128, 25  0           ['up_sampling2d_2[0][0]']
#                                 6)
#
#  multiply_1 (Multiply)          (None, 128, 128, 25  0           ['lambda_1[0][0]',
#                                 6)                                'activation_5[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 25  65792       ['multiply_1[0][0]']
#                                 6)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 51  0          ['activation_14[0][0]']
#                                 2)
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 25  1024       ['conv2d_27[0][0]']
#  ormalization)                  6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 76  0           ['up_sampling2d_3[0][0]',
#                                 8)                                'batch_normalization_21[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 128, 128, 25  1769728     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 25  1024       ['conv2d_28[0][0]']
#  ormalization)                  6)
#
#  activation_18 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_22[0][0]']
#                                 6)
#
#  conv2d_30 (Conv2D)             (None, 128, 128, 25  196864      ['concatenate_1[0][0]']
#                                 6)
#
#  conv2d_29 (Conv2D)             (None, 128, 128, 25  590080      ['activation_18[0][0]']
#                                 6)
#
#  batch_normalization_24 (BatchN  (None, 128, 128, 25  1024       ['conv2d_30[0][0]']
#  ormalization)                  6)
#
#  batch_normalization_23 (BatchN  (None, 128, 128, 25  1024       ['conv2d_29[0][0]']
#  ormalization)                  6)
#
#  add_8 (Add)                    (None, 128, 128, 25  0           ['batch_normalization_24[0][0]',
#                                 6)                                'batch_normalization_23[0][0]']
#
#  activation_19 (Activation)     (None, 128, 128, 25  0           ['add_8[0][0]']
#                                 6)
#
#  conv2d_31 (Conv2D)             (None, 128, 128, 12  32896       ['activation_19[0][0]']
#                                 8)
#
#  batch_normalization_25 (BatchN  (None, 128, 128, 12  512        ['conv2d_31[0][0]']
#  ormalization)                  8)
#
#  activation_20 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_25[0][0]']
#                                 8)
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 12  16512       ['activation_20[0][0]']
#                                 8)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 12  147584     ['conv2d_33[0][0]']
#  spose)                         8)
#
#  conv2d_32 (Conv2D)             (None, 128, 128, 12  65664       ['activation_3[0][0]']
#                                 8)
#
#  add_9 (Add)                    (None, 128, 128, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                'conv2d_32[0][0]']
#
#  activation_21 (Activation)     (None, 128, 128, 12  0           ['add_9[0][0]']
#                                 8)
#
#  conv2d_34 (Conv2D)             (None, 128, 128, 1)  129         ['activation_21[0][0]']
#
#  activation_22 (Activation)     (None, 128, 128, 1)  0           ['conv2d_34[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 1)  0          ['activation_22[0][0]']
#
#  lambda_2 (Lambda)              (None, 256, 256, 12  0           ['up_sampling2d_4[0][0]']
#                                 8)
#
#  multiply_2 (Multiply)          (None, 256, 256, 12  0           ['lambda_2[0][0]',
#                                 8)                                'activation_3[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 12  16512       ['multiply_2[0][0]']
#                                 8)
#
#  up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 25  0          ['activation_19[0][0]']
#                                 6)
#
#  batch_normalization_26 (BatchN  (None, 256, 256, 12  512        ['conv2d_35[0][0]']
#  ormalization)                  8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 38  0           ['up_sampling2d_5[0][0]',
#                                 4)                                'batch_normalization_26[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 256, 256, 12  442496      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_27 (BatchN  (None, 256, 256, 12  512        ['conv2d_36[0][0]']
#  ormalization)                  8)
#
#  activation_23 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_27[0][0]']
#                                 8)
#
#  conv2d_38 (Conv2D)             (None, 256, 256, 12  49280       ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_37 (Conv2D)             (None, 256, 256, 12  147584      ['activation_23[0][0]']
#                                 8)
#
#  batch_normalization_29 (BatchN  (None, 256, 256, 12  512        ['conv2d_38[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_28 (BatchN  (None, 256, 256, 12  512        ['conv2d_37[0][0]']
#  ormalization)                  8)
#
#  add_10 (Add)                   (None, 256, 256, 12  0           ['batch_normalization_29[0][0]',
#                                 8)                                'batch_normalization_28[0][0]']
#
#  activation_24 (Activation)     (None, 256, 256, 12  0           ['add_10[0][0]']
#                                 8)
#
#  conv2d_39 (Conv2D)             (None, 256, 256, 64  8256        ['activation_24[0][0]']
#                                 )
#
#  batch_normalization_30 (BatchN  (None, 256, 256, 64  256        ['conv2d_39[0][0]']
#  ormalization)                  )
#
#  activation_25 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_30[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 256, 256, 64  4160        ['activation_25[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 64  36928      ['conv2d_41[0][0]']
#  spose)                         )
#
#  conv2d_40 (Conv2D)             (None, 256, 256, 64  16448       ['activation_1[0][0]']
#                                 )
#
#  add_11 (Add)                   (None, 256, 256, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_40[0][0]']
#
#  activation_26 (Activation)     (None, 256, 256, 64  0           ['add_11[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 256, 256, 1)  65          ['activation_26[0][0]']
#
#  activation_27 (Activation)     (None, 256, 256, 1)  0           ['conv2d_42[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 512, 512, 1)  0          ['activation_27[0][0]']
#
#  lambda_3 (Lambda)              (None, 512, 512, 64  0           ['up_sampling2d_6[0][0]']
#                                 )
#
#  multiply_3 (Multiply)          (None, 512, 512, 64  0           ['lambda_3[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 512, 512, 64  4160        ['multiply_3[0][0]']
#                                 )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 512, 512, 12  0          ['activation_24[0][0]']
#                                 8)
#
#  batch_normalization_31 (BatchN  (None, 512, 512, 64  256        ['conv2d_43[0][0]']
#  ormalization)                  )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 19  0           ['up_sampling2d_7[0][0]',
#                                 2)                                'batch_normalization_31[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 512, 512, 64  110656      ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 512, 512, 64  256        ['conv2d_44[0][0]']
#  ormalization)                  )
#
#  activation_28 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_32[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 512, 512, 64  12352       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 512, 512, 64  36928       ['activation_28[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 512, 512, 64  256        ['conv2d_46[0][0]']
#  ormalization)                  )
#
#  batch_normalization_33 (BatchN  (None, 512, 512, 64  256        ['conv2d_45[0][0]']
#  ormalization)                  )
#
#  add_12 (Add)                   (None, 512, 512, 64  0           ['batch_normalization_34[0][0]',
#                                 )                                 'batch_normalization_33[0][0]']
#
#  activation_29 (Activation)     (None, 512, 512, 64  0           ['add_12[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 512, 512, 1)  65          ['activation_29[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 512, 512, 1)  4          ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 512, 512, 1)  0           ['batch_normalization_35[0][0]']
#
# ==================================================================================================
# Total params: 39,090,377
# Trainable params: 39,068,871
# Non-trainable params: 21,506
# __________________________________________________________________________________________________
# None
# Epoch 1/150
# 100/100 [==============================] - 636s 6s/step - loss: 0.1041 - accuracy: 0.8068 - jacard_coef: 9.2033e-04 - val_loss: 0.1061 - val_accuracy: 0.8591 - val_jacard_coef: 5.7520e-04
# Epoch 2/150
# 100/100 [==============================] - 146s 1s/step - loss: 0.0823 - accuracy: 0.8188 - jacard_coef: 9.9965e-04 - val_loss: 0.1063 - val_accuracy: 0.8573 - val_jacard_coef: 5.7189e-04
# Epoch 3/150
# 100/100 [==============================] - 149s 1s/step - loss: 0.0713 - accuracy: 0.8271 - jacard_coef: 0.0010 - val_loss: 0.1014 - val_accuracy: 0.8585 - val_jacard_coef: 5.8872e-04
# Epoch 4/150
# 100/100 [==============================] - 154s 2s/step - loss: 0.0623 - accuracy: 0.8279 - jacard_coef: 0.0011 - val_loss: 0.0669 - val_accuracy: 0.8553 - val_jacard_coef: 8.0479e-04
# Epoch 5/150
# 100/100 [==============================] - 151s 2s/step - loss: 0.0575 - accuracy: 0.8275 - jacard_coef: 0.0011 - val_loss: 0.0563 - val_accuracy: 0.8516 - val_jacard_coef: 9.1361e-04
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %% [markdown]
# # convert the history.history dict to a pandas DataFrame and save as csv for future plotting

# %% [markdown]
# Save Simple Unet History

# %%
import pandas as pd    
simple_unet_history_df = pd.DataFrame(simple_unet_history.history) 
with open('unet_100_Leakyrelu_history_df_LRate10e3.csv', mode='w') as f:
    simple_unet_history_df.to_csv(f)

# %% [markdown]
# Save Attention Unet History

# %%
import pandas as pd    
Attention_unet_history_df = pd.DataFrame(Attention_unet_history.history) 
with open('att_Relu_unet_Leaky_history_100EP_df_lr-3.csv', mode='w') as f:
    Attention_unet_history_df.to_csv(f)

# %% [markdown]
# Save Residual Attention Unet History

# %%
import pandas as pd    
Residual_Attention_UNet_history_df = pd.DataFrame(Residual_Attention_UNet_history.history) 
with open('custom_code_att_res_unet_history_df.csv', mode='w') as f:
    Residual_Attention_UNet_history_df.to_csv(f)

# %% [markdown]
# #Check history plots, one model at a time

# %%
#history = simple_unet_history
history = Attention_unet_history
#history = Residual_Attention_UNet_history
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.rcParams["figure.figsize"] = (20,10)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
plt.savefig('myimage.tif', format='svg',figsize=(24, 18), dpi=500)

#acc = history.history['jaccard_coef']
acc = history.history['accuracy']
#val_acc = history.history['val_jaccard_coef']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Jaccard')
plt.legend()
plt.show()

# %% [markdown]
# #Load Simple U-Net

# %%
Unet_model = tf.keras.models.load_model("/content/drive/MyDrive/Final_Unet_Models/Simple_Unet_Leaky_100Ep_Lr_-3/U_Net_100EP_Correct Dataset_LE-3.hdf5", compile=False)

# %% [markdown]
# # Load Res_Att Model

# %%
res_Att_model = tf.keras.models.load_model("/content/drive/MyDrive/Final_Unet_Models/Res_Att_Relu_Unet_Leaky_100Ep_Lr_1e-3/AttResUnet_100epochs_B_focal_Relu.hdf5", compile=False)

# %% [markdown]
# #Load Att_Model

# %%
att_model = tf.keras.models.load_model("/content/drive/MyDrive/Final_Unet_Models/Att_Relu_Unet_Leaky_Lr_1e-3_100Ep/Attention_UNet_100epochs_B_focal_Leakyrelu_Lr-3.hdf5", compile=False)

# %% [markdown]
# ##Test the model on images we held out for testing.

# %%
test_img_generator = image_data_generator.flow_from_directory("/content/drive/MyDrive/Colab Notebooks/data/spilit_x_image_test/", 
                                                              seed=seed, 
                                                              batch_size=100, 
                                                              target_size=(512, 512),
                                                              class_mode=None) #Default batch size 32, if not specified here

test_mask_generator = mask_data_generator.flow_from_directory("/content/drive/MyDrive/Colab Notebooks/data/spilit_y_mask_test/", 
                                                              seed=seed, 
                                                              batch_size=100,
                                                              target_size=(512, 512), 
                                                              color_mode = 'grayscale',   #Read masks in grayscale
                                                              class_mode=None)  #Default batch size 32, if not specified here
# Out:
# Found 100 images belonging to 1 classes.
# Found 100 images belonging to 1 classes.

# %% [markdown]
# #Testing on a few test images

# %%
t = test_img_generator.next()
m = test_mask_generator.next()
for i in range(0,3):
    image = t[i]
    mask = m[i]
    plt.figure(figsize=(12, 6))
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.subplot(1,2,2)
    plt.imshow(mask[:,:,0])
    plt.show()

# %% [markdown]
# # Testing testset with 3 different unet models

# %%
import random
test_img_number = random.randint(0, t.shape[0]-1)
test_img = t[test_img_number]
ground_truth= m[test_img_number]
test_img_input=np.expand_dims(test_img, 0)
prediction = (Unet_model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')
plt.show()

# %% [markdown]
# # Function of TP, TN, FP, FN

# %%
def greytobinary(originalImage):
    
    #im_gray = cv2.cvtColor(originalImage, cv2.COLOR_BGR2GRAY)
    im_gray = originalImage
    thresh = 0
    blackAndWhiteImage = cv2.threshold(im_gray, thresh, 1, cv2.THRESH_BINARY)[1]
    # (thresh, blackAndWhiteImage) = cv2.threshold(grayImage, 127, 255, cv2.THRESH_BINARY)
    
    return blackAndWhiteImage

def Metrics_2(Y_pred,Y_val):
    import seaborn as sns

    FP = len(np.where(Y_pred - Y_val == -1)[0])
    FN = len(np.where(Y_pred - Y_val == 1)[0])
    TP = len(np.where(Y_pred + Y_val == 2)[0])
    TN = len(np.where(Y_pred + Y_val == 0)[0])
    cmat = [
       [TP, FN],
       [FP, TN]
    ]
    
    plt.figure(figsize = (6, 6))
    sns.heatmap(cmat / np.sum(cmat), cmap = "Reds", annot = True, fmt = '.2%', square = 1, linewidth = 2.)
    plt.xlabel("predictions")
    plt.ylabel("real values")
    #plt.show()
    Recall = TP/(TP+FN)
    Precision = TP/(TP+FP)
    Accuracy = (TP+TN)/(TP+FN+TN+FP)
    F1 = 2 * (Precision * Recall)/(Precision + Recall)
    IoU =  TP/(TP+FP+FN)
    DICE = (2 * TP) / (2 * TP+FP+FN)
    return cmat,Recall,Precision,Accuracy,F1,IoU, TP, TN, FP, FN,DICE

# %% [markdown]
# #Calculate Precision, Recall, Accuracy, F1

# %%
import sklearn
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import os
import cv2

total_result = pd.DataFrame()
data=[]
from statistics import mean
#IoU_values = []
for img in range(0, a.shape[0]):
  temp_img = a[img]
  ground_truth=b[img]
  temp_img_input=np.expand_dims(temp_img, 0)
  prediction = (res_model.predict(temp_img_input)[0,:,:,0] > 0.55).astype(np.uint8)

  Y_pred = prediction  
  Y_val = greytobinary(ground_truth)
  Y_val = np.reshape(Y_val,(512,512))
  #greytobinary(ground_truth)
  #print(Y_val)
  Y_val = Y_val.astype(int)
  #print(Y_val)
  Y_pred = 1 - Y_pred
  Y_val  = 1 - Y_val

  cmat, Recall, Precision, Accuracy, F1, IoU, TP, TN, FP, FN, DICE = Metrics_2(Y_pred,Y_val)
  #print(result.results)
  keys = ['cmat','Recall', 'Precision', 'Accuracy', 'F1','IoU', 'TP', 'TN', 'FP', 'FN', 'DICE']
  #keys = ['Recall', 'Precision', 'Accuracy', 'F1','IoU']
  values = [cmat, Recall, Precision, Accuracy, F1, IoU, TP, TN, FP, FN, DICE]
  #values = [result.Recall, result.Precision, result.Accuracy, result.F1, result.IoU]

  zipped = zip(keys, values)
  dic = dict(zipped)
  data.append(dic)
  total_result = total_result.append(data, True)

print("\nMean of Recall is: %f\nMean of Precision is: %f"%(mean(total_result['Recall']),mean(total_result['Precision']))) 
print("Mean of Accuracy is: %f\nMean of F1 is: %f\n"%(mean(total_result['Accuracy']),mean(total_result['F1'])))
print("\nMean of IoU is: %f"%(mean(total_result['IoU'])))
print("\nMean of DICE is: %f"%(mean(total_result['DICE'])))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Mean of Recall is: 0.965574
# Mean of Precision is: 0.986510
# Mean of Accuracy is: 0.959909
# Mean of F1 is: 0.975840
#
#
# Mean of IoU is: 0.953085
#
# Mean of DICE is: 0.975840

# %% [markdown]
# #Visual Bar

# %%
from google.colab import output
#I don't know why nbextensions don't work with python3.6 
with output.temporary():
  # !pip install --upgrade git+https://github.com/Kreijstal/colab_inspector.git 
  # !python2.7 -m pip install --upgrade git+https://github.com/blois/colab_inspector.git #yes, really.
  # !jupyter nbextension install --py inspector

import inspector

# open a scratch cell (Ctrl+Alt+N)
# run there

# %%
# inspector.watch_globals()
inspector.watch_globals()

# %% [markdown]
# #Save segmented image sample

# %%
plt.imsave('/content/drive/MyDrive/Colab Notebooks/output3.png', prediction, cmap = 'binary')
plt.imsave('/content/drive/MyDrive/Colab Notebooks/ground3.png', ground_truth[:,:,0], cmap = 'binary')
plt.imsave('/content/drive/MyDrive/Colab Notebooks/test3.png', test_img)

# %% [markdown]
# #Watershed method for instance Segmentation

# %%
import numpy as np
import cv2
import pandas as pd
import glob
import pickle
from matplotlib import pyplot as plt
from skimage.transform import resize
from skimage import measure, color, io
import os
import pandas as pd
from skimage import data, io
from skimage import data, io

#####Watershed 
def process_images(prediction):
  #img = cv2.imread("/content/drive/MyDrive/Colab Notebooks/output3.png")  #Read as color (3 channels)
  img_grey = prediction
  #img_grey = prediction[:,:,0]
  
# change the unet result to binary image
# Threshold image to binary using OTSU. All thresholded pixels will be set to 255
  ret1, thresh = cv2.threshold(img_grey, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

#plt.imshow(thresh, cmap = 'gray')
# Morphological operations to remove small noise - opening
# To remove holes we can use closing
  kernel = np.ones((3,3),np.uint8)
  opening = cv2.morphologyEx(thresh,cv2.MORPH_OPEN,kernel, iterations = 2)
#plt.imshow(opening, cmap = 'gray')

#Watershed should find this area (Sure_Background) for us. 
  sure_bg = cv2.dilate(opening,kernel,iterations=10)
  #plt.imshow(sure_bg, cmap = 'gray')

# extract sure foreground area using distance transform and thresholding
  dist_transform = cv2.distanceTransform(opening,cv2.DIST_L2,5)

# threshold the dist transform by starting at 1/2 its max value.
  ret2, sure_fg = cv2.threshold(dist_transform, 0.48 *dist_transform.max(),255,0)

# Unknown  region will calculate according to bkground - foreground
  sure_fg = np.uint8(sure_fg)
  unknown = cv2.subtract(sure_bg,sure_fg)


# For sure regions,  foreground and background will be consider and kabel with positive numbers.
# Unknown regions will be labeled 0. 
  ret3, markers = cv2.connectedComponents(sure_fg)

# add 10 to all labels so that sure background will be consider as 10
  markers = markers+10

# Now, mark the region of unknown with zero
  markers[unknown==255] = 0
  prediction = cv2.cvtColor(prediction, cv2.COLOR_GRAY2BGR)
#plt.imshow(markers, cmap='jet')   #Look at the 3 distinct regions.
 
  markers = cv2.watershed(prediction, markers)
  #plt.imshow(markers, cmap='gray')

#boundary region will be marked -1
#color boundaries in yellow. 
  prediction[markers == -1] = [0,255,255]  

  processed = color.label2rgb(markers, bg_label=0)

  props = measure.regionprops_table(markers, intensity_image=img_grey, 
                              properties=['label',
                                          'area', 'equivalent_diameter',
                                          'mean_intensity', 'solidity'])
    
  df = pd.DataFrame(props)
  df = df[df.mean_intensity > 100]  
  #print(dataf.head())
  return df, processed

# %% [markdown]
# #Watershed Segmentation Step

# %%
import random
measurment = pd.DataFrame([])
test_img_number = random.randint(0, t.shape[0]-1)
test_img = t[test_img_number]
ground_truth= m[test_img_number]
test_img_input=np.expand_dims(test_img, 0)
# prediction = prediction
prediction = (Unet_model.predict(test_img_input)[0,:,:,0] > 0.60).astype(np.uint8)
result_table, processed_img = process_images(prediction)
measurment = measurment.append(result_table)
org_1 = test_img
display (measurment)
plt.figure(figsize=(20, 8))
plt.subplot(1,4,1)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(1,4,2)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(1,4,3)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='jet')
plt.subplot(1,4,4)
plt.title('Instance Image')
plt.imshow(processed_img, cmap='jet')
plt.show()
# Out:
# Empty DataFrame
# Columns: [label, area, equivalent_diameter, mean_intensity, solidity]
# Index: []

# %% [markdown]
# #Repeat Watershed to find Best Trheshold

# %%
prediction = (Unet_model.predict(test_img_input)[0,:,:,0] > 0.57).astype(np.uint8)
result_table, processed_img = process_images(prediction)
measurment = measurment.append(result_table)
display (measurment)
plt.figure(figsize=(20, 8))
plt.subplot(1,4,1)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(1,4,2)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(1,4,3)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='jet')
plt.subplot(1,4,4)
plt.title('Instance Image')
plt.imshow(processed_img, cmap='jet')
plt.show()
# Out:
# Empty DataFrame
# Columns: [label, area, equivalent_diameter, mean_intensity, solidity]
# Index: []

# %% [markdown]
# # Visalizing Segmentation Result

# %%
import random
import cv2
import glob
import os
import math
import numpy as np
import cv2
import pandas as pd
import pandas as pd
from skimage import io, color
import matplotlib.pyplot as plt
#main_color = cv2.imread(org_img_dir,cv2.IMREAD_COLOR)
# io.imshow(color.label2rgb(seg_visual,main,colors=[(255,0,0),(0,0,255)],alpha=0.01, bg_label=0, bg_color=None))
prediction = (Unet_model.predict(test_img_input)[0,:,:,0] > 0.55).astype(np.uint8)
seg_visual = np.zeros((512,512)) # create a matrix of zeroes of same size as image
# Load images as greyscale but make main RGB so we can annotate in colour
seg = prediction
seg_visual[seg == 1] = 1   # Change zeroes to label "1" as per your condition(s)
seg_visual[seg == 0] = 2  


test_img2 = test_img
main_color = test_img
#main = cv2.cvtColor(main,cv2.COLOR_GRAY2BGR)

#io.imshow(color.label2rgb(seg_visual,main_color,colors=[(255,0,0),(0,0,255)],alpha=0.1, bg_label=0, bg_color=None))
#plt.show()
#result = io.imshow(color.label2rgb(seg_visual,main_color,colors=[(255,0,0),(0,0,255)],alpha=0.001, bg_label=0, bg_color=None))
plt.imsave('seg_res_2.png', color.label2rgb(seg_visual, main_color,colors=[(255,0,0),(0,128,128)],alpha=0.001, bg_label=0, bg_color=None), cmap = plt.cm.gray)
result = cv2.imread('seg_res_2.png')

#plt.show()

plt.figure(figsize=(30, 8))
plt.subplot(1,5,1)
plt.title('Test Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(1,5,2)
plt.title('Ground Truth')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(1,5,3) 
plt.title('Prediction')
plt.imshow(prediction, cmap='jet')
plt.subplot(1,5,4)
plt.title('Instance Segmentation')
plt.imshow(processed_img, cmap='jet')
#plt.show()
plt.subplot(1,5,5)
plt.title('Visualaize Segmentation Result')
plt.imshow(result)
plt.show()
